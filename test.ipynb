# %%
import pyswcloader

# %%
path = '/home/cdc/data/mouse_data/test'

# %%
path_list = pyswcloader.swc.read_neuron_path(path)
path_list
# Out:
# ['/home/cdc/data/mouse_data/test/192713_031.swc',
#  '/home/cdc/data/mouse_data/test/201225_035.swc',
#  '/home/cdc/data/mouse_data/test/17099_004_reg.swc',
#  '/home/cdc/data/mouse_data/test/195037_054.swc',
#  '/home/cdc/data/mouse_data/test/192713_014.swc',
#  '/home/cdc/data/mouse_data/test/201224_001.swc',
#  '/home/cdc/data/mouse_data/test/192710_019.swc',
#  '/home/cdc/data/mouse_data/test/201225_051.swc',
#  '/home/cdc/data/mouse_data/test/201225_057.swc',
#  '/home/cdc/data/mouse_data/test/17099_003_reg.swc',
#  '/home/cdc/data/mouse_data/test/17100_000_reg.swc',
#  '/home/cdc/data/mouse_data/test/17099_026_reg.swc',
#  '/home/cdc/data/mouse_data/test/192713_028.swc',
#  '/home/cdc/data/mouse_data/test/17100_025_reg.swc',
#  '/home/cdc/data/mouse_data/test/195038_011.swc',
#  '/home/cdc/data/mouse_data/test/192710_026.swc',
#  '/home/cdc/data/mouse_data/test/195037_036.swc',
#  '/home/cdc/data/mouse_data/test/17099_022_reg.swc',
# ...

# %%
pyswcloader.swc.plot_soma_distribution(path)
# Out:
# 100%|██████████| 37/37 [00:00<00:00, 103.34it/s]
#              x           y           z
# 0   6585.42000  6817.70000  5916.14000
# 1   7755.17000  5978.52000  5057.95000
# 2   3276.04724  2512.74327  7189.18085
# 3   5967.70000  5487.52000  5862.00000
# 4   6840.02000  6601.49000  5372.39000
# 5   5473.00000  6190.06000  6509.35000
# 6   5517.45000  4976.68000  6635.54000
# 7   7115.69000  5335.25000  4562.41000
# 8   6877.77000  5659.60000  4818.28000
# 9   2531.44977  3065.55402  5242.73243
# 10  2649.87104  3320.45776  6695.13693
# 11  2604.19698  3107.94083  6255.00820
# 12  6876.17000  7056.20000  6076.37000
# 13  2793.51212  2373.45540  3967.31668
# 14  5974.78000  5536.06000  5477.30000
# 15  5585.17000  4860.23000  6756.16000
# 16  6154.92000  5583.95000  5897.46000
# 17  2532.92678  2959.82144  6350.86645
# 18  3263.10339  2543.90272  7124.44665
# 19  6919.38000  5391.96000  4504.83000
# 20  7168.28000  6097.76000  4957.89000
# 21  6061.88000  5549.76000  5930.59000
# ...
